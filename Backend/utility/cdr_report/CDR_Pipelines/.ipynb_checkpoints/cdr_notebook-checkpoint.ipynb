# %%
os.getcwd()
# Out:
# 'C:\\Users\\affine\\Downloads\\InterTek-AI-Repo\\Backend\\utility\\cdr_report\\CDR_Pipelines'

# %%
os.chdir(r"C:\Users\affine\Downloads\InterTek-AI-Repo\Backend")
print(os.getcwd())
# Out:
# C:\Users\affine\Downloads\InterTek-AI-Repo\Backend

# %%
import os
import json
import time
import shutil
from pathlib import Path
from urllib.parse import quote

from utility.cdr_report.CDR_Pipelines.configs import (
    init_runtime,
    clear_runtime,
    project_paths,
    cosmos_client,
    AZURE_BLOB_CONNECTION_STRING,
    BLOB_CONTAINER_NAME,
    AZURE_CONN_STRING,
    container,
    DB_NAME
)

import utility.cdr_report.CDR_Pipelines.configs as configs

from utility.cdr_report.CDR_Pipelines.postprocessor import post_process_cdr
from utility.cdr_report.CDR_Pipelines.form_utils import build_ref
from utility.cdr_report.CDR_Pipelines.references import references_main
from utility.cdr_report.CDR_Pipelines.features_agent import features_tools_main
from utility.cdr_report.CDR_Pipelines.description import description_main, build_product_section_items
from utility.cdr_report.CDR_Pipelines.components_agent import run_sheet_3_and_4_agentic
import utility.cdr_report.CDR_Pipelines.compiler as compiler
import utility.cdr_report.CDR_Pipelines.utils as utils
from utility.cdr_report.CDR_Pipelines.utils import get_image_urls_from_container_sas, move_device_images_in_blob, get_blob_urls
from utility.cdr_report.CDR_Pipelines.editable_processing import extract_cis
from langchain_azure_ai.vectorstores import AzureCosmosDBNoSqlVectorSearch
# Out:
# Running in LOCAL mode – using .env

# %%
# --------------------------------------------------
# Helper Functions
# --------------------------------------------------

def progress(step: int, total: int, msg: str, extra=None):
    payload = {
        "type": "progress",
        "step": step,
        "total": total,
        "percent": round((step / total) * 100, 2),
        "message": msg,
        "ts": time.time(),
    }
    if extra:
        payload["extra"] = extra
    print(json.dumps(payload), flush=True)

def get_trf_blob_url(conn_str, container, blob_name):
    p = dict(x.split("=", 1) for x in conn_str.split(";") if "=" in x)
    return f"{p['BlobEndpoint'].rstrip('/')}/{container}/{quote(blob_name, safe='/')}?{p['SharedAccessSignature'].lstrip('?')}"


def build_vectorstore():
    ctx = configs.require_runtime()
    COSMOS_CONTAINER_NAME = configs.build_cosmos_cont_name()
    return AzureCosmosDBNoSqlVectorSearch(
        cosmos_client=cosmos_client,
        embedding=utils.build_embeddings(),
        database_name=configs.COSMOS_DB_NAME,
        container_name=COSMOS_CONTAINER_NAME,
        vector_embedding_policy={
            "vectorEmbeddings": [{
                "path": "/vector",
                "dataType": "float32",
                "dimensions": configs.EMBED_DIM,
                "distanceFunction": "cosine"
            }]
        },
        indexing_policy={
            "includedPaths": [{"path": "/*"}],
            "excludedPaths": [{"path": "/\"_etag\"/?"}, {"path": "/vector/*"}],
            "vectorIndexes": [{"path": "/vector", "type": "quantizedFlat"}],
        },
        cosmos_container_properties={"partition_key": "/id"},
        cosmos_database_properties={},
        vector_search_fields={
            "text_field": "text",
            "embedding_field": "vector",
            "metadata_field": "metadata"
        }
    )

# %%
# --------------------------------------------------
# Initialize Project Directories & IDs
# --------------------------------------------------

project_id = 'B105581614'
user_id = "test_user"
projectId = project_id

BASE_DIR = Path(os.getcwd())
print(f"BASE_DIR : {BASE_DIR}")

DATA_DIR = BASE_DIR/"data"
DATA_DIR.mkdir(parents=True, exist_ok=True)

project_dir = DATA_DIR / projectId
project_dir.mkdir(parents=True, exist_ok=True)

output_json_path = project_dir / f"iec_output_cdr_{projectId}.json"
output_excel_path = project_dir / f"iec_output_sheet_{projectId}.xlsx"


trf_json= project_dir / f"final_output.json"

with open(trf_json, "r", encoding="utf-8") as f:
    input_json = json.load(f)


clear_runtime(project_id=project_id, user_id=user_id)
init_runtime(project_id=project_id, user_id=user_id)
# Out:
# RuntimeContext(project_id='B105581614', user_id='test_user', base_dir=WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614'))

# %%
# trf_json= project_dir / f"final_output.json"

# with open(trf_json, "r", encoding="utf-8") as f:
#     input_json = json.load(f)
    
#input_json
# Out:
# {'Tables': [{'Table': 0,
#    'Items': [{'question_row': 0,
#      'question_column': 3,
#      'field': 'Test Report issued under the responsibility of:',
#      'answer_row': 0,
#      'answer_column': 4,
#      'value': None,
#      'task_type': None,
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1,
#      'disable_text': True},
#     {'question_row': 1,
#      'question_column': 0,
#      'field': 'TEST REPORT\nIEC 61010-1\nSafety requirements for electrical equipment for measurement, \ncontrol, and laboratory use\nPart 1: General requirements',
#      'answer_row': 1,
#      'answer_column': 2,
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1,
#      'disable_text': True},
#     {'question_row': 3,
#      'question_column': 0,
#      'field': 'Report Number.\t:',
#      'answer_row': 3,
#      'answer_column': 2,
#      'value': None,
#      'task_type': None,
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 4,
#      'question_column': 0,
#      'field': 'Date of issue\t:',
#      'answer_row': 4,
#      'answer_column': 2,
#      'value': None,
#      'task_type': None,
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 5,
#      'question_column': 0,
#      'field': 'Total number of pages\t:',
#      'answer_row': 5,
#      'answer_column': 2,
#      'value': None,
#      'task_type': None,
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 7,
#      'question_column': 0,
#      'field': 'Name of Testing Laboratory preparing the Report\t:',
#      'answer_row': 7,
#      'answer_column': 2,
#      'value': None,
#      'task_type': None,
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 8,
#      'question_column': 0,
#      'field': 'Applicant’s name\t:',
#      'answer_row': 8,
#      'answer_column': 1,
#      'value': 'Gener8 LLC',
#      'task_type': 'extraction',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': True,
#      'page_no': 1,
#      'custom_prompt': 'Mention the name of the client.',
#      'text_support': [{'filename': 'Qu-01390131-0.pdf',
#        'page': 11,
#        'similarity_score': 0.7844379003892393,
#        'preview_text': 'Quote No:  Qu-01390131-0\n12 of 14\nINTERTEK - 1365 Adams Court, ,Menlo Park, California, 94025,United States\ncircumstances, infringe any legal rights (including Intellectual Property Rights) of any third party.\n4.2 In the event that the Services provided relate to any third party, the Client shall cause any such third party to acknowledge and agree to the provisions in this \nAgreement and the Proposal prior to and as a condition precedent to such third party receiving any Reports or the benefit of any Services.\n4.3 The Client further agrees:\n(a) to co-operate with Intertek in all matters relating to the Services and appoint a manager in relation to the Services who shall be duly authorized to provide \ninstructions to Intertek on behalf of the Client and to bind the Client contractually as required;\n(b) to provide Intertek (including its agents, sub-contractors and employees), at its own expense, any and all samples, information, material or other documentation',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 10,
#        'similarity_score': 0.7830561280292271,
#        'preview_text': '4. CLIENT WARRANTIES AND OBLIGATIONS\n4.1 The Client represents and warrants:\n(a) that it has the power and authority to enter into this Agreement and procure the provision of the Services for itself;\n(b) that it is securing the provision of the Services hereunder for its own account and not as an agent or broker, or in any other representative capacity, for any \nother person or entity;\n(c) that any information, samples and related documents it (or any of its agents or representatives) supplies to Intertek (including its agents, sub-contractors and \nemployees) is, true, accurate representative, complete and is not misleading in any respect. The Client further acknowledges that Intertek will rely on such \ninformation, samples or other related documents and materials provided by the Client (without any duty to confirm or verify the accuracy or completeness thereof) \nin order to provide the Services;',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 10,
#        'similarity_score': 0.7751506419637137,
#        'preview_text': "with the Client in relation to the Proposal and pursuant to the Client's specific instructions or, in the absence of such instructions, in accordance with any relevant \ntrade custom, usage or practice. The Client further agrees and acknowledges that the Services are not designed or intended to address all matters of quality, safety, \nperformance or condition of any product, material, services, systems or processes tested, inspected or certified and the scope of work does not necessarily reflect \nall standards which may apply to product, material, services, systems or process tested, inspected or certified. The Client understands that reliance on any Reports \nissued by Intertek is limited to the facts and representations set out in the Reports which represent Intertek’s review and/or analysis of facts, information, \ndocuments, samples and/or other materials in existence at the time of the performance of the Services only.",
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 9,
#        'similarity_score': 0.7732712166128226,
#        'preview_text': 'Name Printed\nBeing an authorized representative of:\n__________________________________________________________ \nLegally Registered Business name of the Company who is authorizing commencement of this quotation\n_________________________  ___________________________     ____________________ \nAcceptance Date Preferred Project Start Date    Purchase Order #\nThank you for choosing Intertek!\nSincerely,\nCharlotte Johnson\nSales Representative\n1365 Adams Court\nMenlo Park, California 94025\nUnited States\n1 650 223-9986\ncharlotte.johnson@intertek.com\nQuote #:  Qu-01390131-0\nQuote Issued Date: September 8, 2023\nGener8 LLC\n2560 Junction Ave\nSan Jose, CA 95134\nUSA',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 11,
#        'similarity_score': 0.7697745982387012,
#        'preview_text': 'Intertek (such consent not to be unreasonably withheld) in each instance; and\n(m) that any and all advertising and promotional materials or any statements made by the Client will not give a false or misleading impression to any third party \nconcerning the services provided by Intertek.\n4.4 Intertek shall be neither in breach of this Agreement nor liable to the Client for any breach of this Agreement if and to the extent that its breach is a direct result \nof a failure by the Client to comply with its obligations as set out in this Clause 4. The Client also acknowledges that the impact of any failure by the Client to \nperform its obligations set out herein on the provision of the Services by Intertek will not affect the Client’s obligations under this Agreement for payment of the \nCharges pursuant to Clause 5 below.\n5. CHARGES, INVOICING AND PAYMENT',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'}],
#      'image_support': [{'filename': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf_page_1.png',
#        'image_file': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf_page_1.png',
#        'pdf_file': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf/page_1.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf'},
#       {'filename': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf_page_1.png',
#        'image_file': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf_page_1.png',
#        'pdf_file': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf/page_1.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx'}],
#      'evidence_type': 'both',
#      'confidence': 100},
#     {'question_row': 9,
#      'question_column': 0,
#      'field': 'Address\t:',
#      'answer_row': 9,
#      'answer_column': 1,
#      'value': '2560 Junction Ave, San Jose, CA 95134, USA',
#      'task_type': 'extraction',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': True,
#      'page_no': 1,
#      'custom_prompt': 'Mention the address of the client.',
#      'text_support': [{'filename': 'Qu-01390131-0.pdf',
#        'page': 11,
#        'similarity_score': 0.7872575004418259,
#        'preview_text': 'Quote No:  Qu-01390131-0\n12 of 14\nINTERTEK - 1365 Adams Court, ,Menlo Park, California, 94025,United States\ncircumstances, infringe any legal rights (including Intellectual Property Rights) of any third party.\n4.2 In the event that the Services provided relate to any third party, the Client shall cause any such third party to acknowledge and agree to the provisions in this \nAgreement and the Proposal prior to and as a condition precedent to such third party receiving any Reports or the benefit of any Services.\n4.3 The Client further agrees:\n(a) to co-operate with Intertek in all matters relating to the Services and appoint a manager in relation to the Services who shall be duly authorized to provide \ninstructions to Intertek on behalf of the Client and to bind the Client contractually as required;\n(b) to provide Intertek (including its agents, sub-contractors and employees), at its own expense, any and all samples, information, material or other documentation',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 9,
#        'similarity_score': 0.7726589989998148,
#        'preview_text': 'Name Printed\nBeing an authorized representative of:\n__________________________________________________________ \nLegally Registered Business name of the Company who is authorizing commencement of this quotation\n_________________________  ___________________________     ____________________ \nAcceptance Date Preferred Project Start Date    Purchase Order #\nThank you for choosing Intertek!\nSincerely,\nCharlotte Johnson\nSales Representative\n1365 Adams Court\nMenlo Park, California 94025\nUnited States\n1 650 223-9986\ncharlotte.johnson@intertek.com\nQuote #:  Qu-01390131-0\nQuote Issued Date: September 8, 2023\nGener8 LLC\n2560 Junction Ave\nSan Jose, CA 95134\nUSA',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 11,
#        'similarity_score': 0.7700414747689744,
#        'preview_text': 'Services and to any other relevant premises at which the Services are to be provided;\n(f) prior to Intertek attending any premises for the performance of the Services, to inform Intertek of all applicable health and safety rules and regulations and other \nreasonable security requirements that may apply at any relevant premises at which the Services are to be provided;\n(g) to notify Intertek promptly of any risk, safety issues or incidents in respect of any item delivered by the Client, or any process or systems used at its premises or \notherwise necessary for the provision of the Services;\n(h) to inform Intertek in advance of any applicable import/export restrictions that may apply to the Services to be provided, including any instances where any \nproducts, information or technology may be exported/ imported to or from a country that is restricted or banned from such transaction;',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 11,
#        'similarity_score': 0.7685210418834199,
#        'preview_text': 'necessary for the execution of the Services in a timely manner sufficient to enable Intertek to provide the Services in accordance with this Agreement. The Client \nacknowledges that any samples provided may become damaged or be destroyed in the course of testing as part of the necessary testing process and undertakes to \nhold Intertek harmless from any and all responsibility for such alteration, damage or destruction;\n(c) that it is responsible for providing the samples/equipment to be tested together, where appropriate, with any specified additional items, including but not \nlimited to connecting pieces, fuse-links, etc.;\n(d) to provide instructions and feedback to Intertek in a timely manner;\n(e) to provide Intertek (including its agents, sub-contractors and employees) with access to its premises as may be reasonably required for the provision of the \nServices and to any other relevant premises at which the Services are to be provided;',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 10,
#        'similarity_score': 0.7640348594434089,
#        'preview_text': "with the Client in relation to the Proposal and pursuant to the Client's specific instructions or, in the absence of such instructions, in accordance with any relevant \ntrade custom, usage or practice. The Client further agrees and acknowledges that the Services are not designed or intended to address all matters of quality, safety, \nperformance or condition of any product, material, services, systems or processes tested, inspected or certified and the scope of work does not necessarily reflect \nall standards which may apply to product, material, services, systems or process tested, inspected or certified. The Client understands that reliance on any Reports \nissued by Intertek is limited to the facts and representations set out in the Reports which represent Intertek’s review and/or analysis of facts, information, \ndocuments, samples and/or other materials in existence at the time of the performance of the Services only.",
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'}],
#      'image_support': [{'filename': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf_page_1.png',
#        'image_file': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf_page_1.png',
#        'pdf_file': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf/page_1.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf'}],
#      'evidence_type': 'both',
#      'confidence': 100},
#     {'question_row': 10,
#      'question_column': 0,
#      'field': 'Test specification:',
#      'answer_row': 10,
#      'answer_column': 1,
#      'task_type': None,
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1,
#      'single_row': True},
#     {'question_row': 11,
#      'question_column': 0,
#      'field': 'Standard\t:',
#      'answer_row': 11,
#      'answer_column': 1,
#      'value': 'IEC 61010-1:2010, IEC 61010-1:2010/AMD1:2016',
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 12,
#      'question_column': 0,
#      'field': 'Test procedure\t:',
#      'answer_row': 12,
#      'answer_column': 1,
#      'value': 'CB Scheme',
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 13,
#      'question_column': 0,
#      'field': 'Non-standard test method\t:',
#      'answer_row': 13,
#      'answer_column': 1,
#      'value': 'N/A',
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 14,
#      'question_column': 0,
#      'field': 'TRF template used\t:',
#      'answer_row': 14,
#      'answer_column': 1,
#      'value': 'IECEE OD-2020-F1:2020, Ed.1.3',
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 15,
#      'question_column': 0,
#      'field': 'Test Report Form No.\t:',
#      'answer_row': 15,
#      'answer_column': 1,
#      'value': 'IEC61010_1P',
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 16,
#      'question_column': 0,
#      'field': 'Test Report Form(s) Originator\t:',
#      'answer_row': 16,
#      'answer_column': 1,
#      'value': 'VDE Prüf- und Zertifizierungsinstitut GmbH',
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 17,
#      'question_column': 0,
#      'field': 'Master TRF\t:',
#      'answer_row': 17,
#      'answer_column': 1,
#      'value': '2021-04-12',
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1},
#     {'question_row': 18,
#      'question_column': 0,
#      'field': "Copyright © 2021 IEC System of Conformity Assessment Schemes for Electrotechnical Equipment and Components (IECEE System). All rights reserved.\nThis publication may be reproduced in whole or in part for non-commercial purposes as long as the IECEE is acknowledged as copyright owner and source of the material. IECEE takes no responsibility for and will not assume liability for damages resulting from the reader's interpretation of the reproduced material due to its placement and context.\nIf this Test Report Form is used by non-IECEE members, the IECEE/IEC logo and the reference to the CB Scheme procedure shall be removed.\nThis report is not valid as a CB Test Report unless signed by an approved IECEE Testing Laboratory and appended to a CB Test Certificate issued by an NCB in accordance with IECEE 02.",
#      'answer_row': 18,
#      'answer_column': 1,
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1,
#      'single_row': True},
#     {'question_row': 19,
#      'question_column': 0,
#      'field': 'General disclaimer:\nThe test results presented in this report relate only to the object tested.\nThis report shall not be reproduced, except in full, without the written approval of the Issuing  NCB. The authenticity of this Test Report and its contents can be verified by contacting the NCB, responsible for this Test Report.',
#      'answer_row': 20,
#      'answer_column': 0,
#      'task_type': None,
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'page_no': 1,
#      'single_row': True}]},
#   {'Table': 1,
#    'Items': [{'question_row': 0,
#      'question_column': 0,
#      'field': 'Test item description\t:',
#      'answer_row': 0,
#      'answer_column': 2,
#      'value': 'CellFE Infinity MTx Instrument',
#      'task_type': 'extraction',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': True,
#      'page_no': 2,
#      'custom_prompt': 'Mention the name of the product.',
#      'text_support': [{'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 1,
#        'similarity_score': 0.7904600516053446,
#        'preview_text': 'Page 2 of 59 \n \nTable of Contents \nChapter 1. Product Information ............................................................................................. 5 \nProduct Description ............................................................................................................... 5 \nKey Benefits .......................................................................................................................... 5 \nProduct Contents ................................ ................................ ................................ ........................... 6 \nSystem contents ................................................................................................................................................... 6 \nOptimizer kit contents ......................................................................................................................................... 7',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 50,
#        'similarity_score': 0.785111779758193,
#        'preview_text': 'the manufacturer at the address provided in this manual . \n                Proposition 65 warning \nThis product can expose you to chemicals including Nickel (metallic) which are known to the State of California to \ncause cancer or birth defects or other reproductive harm. For more information, visit www.P65Warnings.ca.gov.',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf',
#        'page': 0,
#        'similarity_score': 0.7716203395809953,
#        'preview_text': 'this list, or are the product(s) on which services will be performed originating from or \ndestined for a Sanctioned Country?  LINK2   \nRequired to comply with national and international regulations.  \n☐YES    ☒NO \n1.4 Is the product subject to Import/Export Controls and Regulations (e.g., International \nTraffic and Arms Regulations (ITAR), Export Administration Regulations (EAR))?   \nThis may involve military, defence or dual-use products and is required to comply with special project \nmanagement, record storage, and export handling requirements.  If testing is to MIL461, MIL704, \nMIL810, ATPD2352, ANSIZ26.1, or RTCA-DO-160, select “Yes” The Export Control Classification \nNumber (ECCN) must be submitted with the RAF to RCO for review. \n☐YES    ☒NO \nIf you answered “YES” to any question in Section 1, no quote may be issued.   \nTo request an exception, the opportunity must be reviewed and approved by Regional Compliance Officer (RCO).',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 9,
#        'similarity_score': 0.7692298786857642,
#        'preview_text': 'Name Printed\nBeing an authorized representative of:\n__________________________________________________________ \nLegally Registered Business name of the Company who is authorizing commencement of this quotation\n_________________________  ___________________________     ____________________ \nAcceptance Date Preferred Project Start Date    Purchase Order #\nThank you for choosing Intertek!\nSincerely,\nCharlotte Johnson\nSales Representative\n1365 Adams Court\nMenlo Park, California 94025\nUnited States\n1 650 223-9986\ncharlotte.johnson@intertek.com\nQuote #:  Qu-01390131-0\nQuote Issued Date: September 8, 2023\nGener8 LLC\n2560 Junction Ave\nSan Jose, CA 95134\nUSA',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 31,
#        'similarity_score': 0.7686666396275208,
#        'preview_text': 'Operator Selection Screen and \ncontact customer support. \nConsumable not recognized. \nPlease return to Home. \nThe device barcode is being \nread but is unable to be \nrecognized by system. \nThe user should return to the \nOperator Selection Screen and \ncontact customer support to \nreplace faulty device.',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'}],
#      'image_support': [{'filename': 'CFE-4LB011-E__1___1_.pdf_page_1.png',
#        'image_file': 'CFE-4LB011-E__1___1_.pdf_page_1.png',
#        'pdf_file': 'CFE-4LB011-E__1___1_.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/CFE-4LB011-E__1___1_.pdf/page_1.png',
#        'file_url': None},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf_page_6.png',
#        'image_file': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf_page_6.png',
#        'pdf_file': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 6,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf/page_6.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'}],
#      'evidence_type': 'both',
#      'confidence': 100},
#     {'question_row': 1,
#      'question_column': 0,
#      'field': 'Trade Mark\t:',
#      'answer_row': 1,
#      'answer_column': 2,
#      'value': 'Gener8 LLC',
#      'task_type': 'extraction',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': True,
#      'page_no': 2,
#      'custom_prompt': 'Mention the name of the client.',
#      'text_support': [{'filename': 'Qu-01390131-0.pdf',
#        'page': 11,
#        'similarity_score': 0.7844379003892393,
#        'preview_text': 'Quote No:  Qu-01390131-0\n12 of 14\nINTERTEK - 1365 Adams Court, ,Menlo Park, California, 94025,United States\ncircumstances, infringe any legal rights (including Intellectual Property Rights) of any third party.\n4.2 In the event that the Services provided relate to any third party, the Client shall cause any such third party to acknowledge and agree to the provisions in this \nAgreement and the Proposal prior to and as a condition precedent to such third party receiving any Reports or the benefit of any Services.\n4.3 The Client further agrees:\n(a) to co-operate with Intertek in all matters relating to the Services and appoint a manager in relation to the Services who shall be duly authorized to provide \ninstructions to Intertek on behalf of the Client and to bind the Client contractually as required;\n(b) to provide Intertek (including its agents, sub-contractors and employees), at its own expense, any and all samples, information, material or other documentation',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 10,
#        'similarity_score': 0.7830561280292271,
#        'preview_text': '4. CLIENT WARRANTIES AND OBLIGATIONS\n4.1 The Client represents and warrants:\n(a) that it has the power and authority to enter into this Agreement and procure the provision of the Services for itself;\n(b) that it is securing the provision of the Services hereunder for its own account and not as an agent or broker, or in any other representative capacity, for any \nother person or entity;\n(c) that any information, samples and related documents it (or any of its agents or representatives) supplies to Intertek (including its agents, sub-contractors and \nemployees) is, true, accurate representative, complete and is not misleading in any respect. The Client further acknowledges that Intertek will rely on such \ninformation, samples or other related documents and materials provided by the Client (without any duty to confirm or verify the accuracy or completeness thereof) \nin order to provide the Services;',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 10,
#        'similarity_score': 0.7751506419637137,
#        'preview_text': "with the Client in relation to the Proposal and pursuant to the Client's specific instructions or, in the absence of such instructions, in accordance with any relevant \ntrade custom, usage or practice. The Client further agrees and acknowledges that the Services are not designed or intended to address all matters of quality, safety, \nperformance or condition of any product, material, services, systems or processes tested, inspected or certified and the scope of work does not necessarily reflect \nall standards which may apply to product, material, services, systems or process tested, inspected or certified. The Client understands that reliance on any Reports \nissued by Intertek is limited to the facts and representations set out in the Reports which represent Intertek’s review and/or analysis of facts, information, \ndocuments, samples and/or other materials in existence at the time of the performance of the Services only.",
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 9,
#        'similarity_score': 0.7732712166128226,
#        'preview_text': 'Name Printed\nBeing an authorized representative of:\n__________________________________________________________ \nLegally Registered Business name of the Company who is authorizing commencement of this quotation\n_________________________  ___________________________     ____________________ \nAcceptance Date Preferred Project Start Date    Purchase Order #\nThank you for choosing Intertek!\nSincerely,\nCharlotte Johnson\nSales Representative\n1365 Adams Court\nMenlo Park, California 94025\nUnited States\n1 650 223-9986\ncharlotte.johnson@intertek.com\nQuote #:  Qu-01390131-0\nQuote Issued Date: September 8, 2023\nGener8 LLC\n2560 Junction Ave\nSan Jose, CA 95134\nUSA',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 11,
#        'similarity_score': 0.7697745982387012,
#        'preview_text': 'Intertek (such consent not to be unreasonably withheld) in each instance; and\n(m) that any and all advertising and promotional materials or any statements made by the Client will not give a false or misleading impression to any third party \nconcerning the services provided by Intertek.\n4.4 Intertek shall be neither in breach of this Agreement nor liable to the Client for any breach of this Agreement if and to the extent that its breach is a direct result \nof a failure by the Client to comply with its obligations as set out in this Clause 4. The Client also acknowledges that the impact of any failure by the Client to \nperform its obligations set out herein on the provision of the Services by Intertek will not affect the Client’s obligations under this Agreement for payment of the \nCharges pursuant to Clause 5 below.\n5. CHARGES, INVOICING AND PAYMENT',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'}],
#      'image_support': [{'filename': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf_page_1.png',
#        'image_file': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf_page_1.png',
#        'pdf_file': 'Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf/page_1.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf'},
#       {'filename': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf_page_1.png',
#        'image_file': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf_page_1.png',
#        'pdf_file': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf/page_1.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx'}],
#      'evidence_type': 'both',
#      'confidence': 100},
#     {'question_row': 2,
#      'question_column': 0,
#      'field': 'Manufacturer\t:',
#      'answer_row': 2,
#      'answer_column': 2,
#      'value': 'CellFE, Inc.',
#      'task_type': 'extraction',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': True,
#      'page_no': 2,
#      'custom_prompt': 'Mention the name of the Manufacturer.',
#      'text_support': [{'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 50,
#        'similarity_score': 0.8075509096190444,
#        'preview_text': 'the manufacturer at the address provided in this manual . \n                Proposition 65 warning \nThis product can expose you to chemicals including Nickel (metallic) which are known to the State of California to \ncause cancer or birth defects or other reproductive harm. For more information, visit www.P65Warnings.ca.gov.',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'Qu-01390131-0.pdf',
#        'page': 9,
#        'similarity_score': 0.7753189774672555,
#        'preview_text': 'Name Printed\nBeing an authorized representative of:\n__________________________________________________________ \nLegally Registered Business name of the Company who is authorizing commencement of this quotation\n_________________________  ___________________________     ____________________ \nAcceptance Date Preferred Project Start Date    Purchase Order #\nThank you for choosing Intertek!\nSincerely,\nCharlotte Johnson\nSales Representative\n1365 Adams Court\nMenlo Park, California 94025\nUnited States\n1 650 223-9986\ncharlotte.johnson@intertek.com\nQuote #:  Qu-01390131-0\nQuote Issued Date: September 8, 2023\nGener8 LLC\n2560 Junction Ave\nSan Jose, CA 95134\nUSA',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 50,
#        'similarity_score': 0.7682582419162877,
#        'preview_text': 'Page 51 of 59 \n9. Support: For inquiries related to biohazard safety, disposal, and MSDS specific to this product, please \ncontact the manufacturer at the address provided above For information regarding safe disposal of materials \nplease contact your local regulatory agency, \n \n \n \n WEEE Directive Statement \nElectronic and Electrical Equipment  placed onto the market in Europe are marked with the crossed -out \nwheeled bin symbol to indicate that they are covered by the WEEE Directive ( 2012/19/EU) , which imposes \na number of obligations on producers of EEE including obligations relating to the financing of the take -\nback treatment and recycling of end of life equipment (WEEE).  \nTo ensure proper disposal and recycling of this product, please follow the guidelines provided below: \n1. End-of-Life Disposal: Do not dispose of this product with regular household waste. It is your responsibility to \nproperly dispose of this product at the end of its life cycle.',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf',
#        'page': 2,
#        'similarity_score': 0.7638232169812844,
#        'preview_text': 'Examples: failure of a product manufactured by another company, failure of a product bearing an Intertek \nname, logo, or Mark (e.g., ETL, WH). Failures may include a wide range of events including: breakage, \ndecreased functionality, fire, personal injury, property damage.  \n \n \n☐YES    ☒NO \n \n \n \n \n☐YES    ☒NO \n \n \n☐YES    ☒NO \n \n \n \n☐YES    ☒NO \nIf you answered “YES” to any question in Section 4, a quote may not be issued without written approval from Regional \nCompliance Officer (RCO).  Forward the RAF and Project Details to RCO.  \n \nRAF DECISION TO BE COMPLETED BY REGIONAL COMPLIANCE OFFICER (RCO) \nDate:       \nDecision and Rationale:       \nRegional Compliance Officer Name/Signature:       \n☐APPROVED  \n \n☐CONDITIONALLY \nAPPROVED  \n \n☐DENIED',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 31,
#        'similarity_score': 0.7629526961280964,
#        'preview_text': 'Operator Selection Screen and \ncontact customer support. \nConsumable not recognized. \nPlease return to Home. \nThe device barcode is being \nread but is unable to be \nrecognized by system. \nThe user should return to the \nOperator Selection Screen and \ncontact customer support to \nreplace faulty device.',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'}],
#      'image_support': [{'filename': 'CFE-4LB011-E__1___1_.pdf_page_1.png',
#        'image_file': 'CFE-4LB011-E__1___1_.pdf_page_1.png',
#        'pdf_file': 'CFE-4LB011-E__1___1_.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/CFE-4LB011-E__1___1_.pdf/page_1.png',
#        'file_url': None}],
#      'evidence_type': 'image',
#      'confidence': 100},
#     {'question_row': 3,
#      'question_column': 0,
#      'field': 'Model/Type reference\t:',
#      'answer_row': 3,
#      'answer_column': 2,
#      'value': 'Infinity MTx, Optimizer kits A, B, C',
#      'task_type': 'extraction',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': True,
#      'page_no': 2,
#      'custom_prompt': 'Mention the model variants of the equipment.',
#      'text_support': [{'filename': 'Qu-01390131-0.pdf',
#        'page': 2,
#        'similarity_score': 0.8075925092608426,
#        'preview_text': 'documents\n•Assumes single model to be tested based on determination of worst case sample. Additional \ntesting across multiple model versions may result in a change order.\n•Assumes Equipment/Product is not relied upon or critical for safety (i.e., is not relied upon to \nperform actions such as shutdown upstream or downstream processes, etc.)\n•Assumes all critical components including off the shelf power supplies are approved for their \nintended markets and used within their intended ratings. Components to be provided with their \nrespective datasheets, approval information/DoC/CoC/CoA/CoI. Additional limited evaluations \nof components are not covered by the scope of this quote\n•Alternate components might be subjected to additional charges for evaluation for conformity \ndependent on quantity and complexity of components\n•Assumes device can be operated continuously without operator intervention\n•Assumes no lasers or UV testing.',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Qu-01390131-0.pdf'},
#       {'filename': 'RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml',
#        'page': 1,
#        'similarity_score': 0.7956848266437571,
#        'preview_text': "Best regards,\nKenneth Tutor\nSafety Engineer\nHi Roberto/Grant,\nI talked to my reviewer and team lead regarding the changes you'd like to make to the air tank. Replacing the current air tank (AVT-32-16) with the models you've mentioned (AVT-17-2 and -3) should be fine. Just note that this particular component will be included in the critical components list of the report. For documentation and transparency, can you also provide the ratings for the current air tank model and the models you'd like to swap it with. Also, will the AVT-17-2 and AVT-17-3 models be alternates or will you only be using one instead of the other?\nBest regards,\nKenneth Tutor\nSAFETY ENGINEER\nHi Kenneth,",
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 42,
#        'similarity_score': 0.78161381224754,
#        'preview_text': 'European Community provisions for which this marking is required. \nOperation of the Infinity Mtx Instrument is subject to the conditions \ndescribed in this manual. The protection provided by the device may be \nimpaired if the instrument is used in a manner not specified by the \nmanufacturer.',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf',
#        'page': 1,
#        'similarity_score': 0.7779842320563933,
#        'preview_text': 'and/or app remote control for use with one of the following product types: a product or appliance \nintended to generate heat (e.g., cooking or personal care products; but does not include room or   \nportable heaters), exercise equipment, spa/whirlpool, any product identified in RAF Section 3.1b \nList for ETL/WH Marks, or a new/unusual product?  May require special review, handling and additional \noversight by Chief Engineering. \n☐YES    ☒NO \nIf you answered “YES” to any question in Section 2, a quote may not be issued without written approval from Chief \nEngineering or Regional Compliance Officer (RCO).  Forward the RAF and Project Details to Chief Engineer and RCO.   \nChief Engineer Name:        \nChief Engineer Recommendation:         \n \n \nSECTION 3: PROJECT RISK ASSESSMENT \n3.1 Product Type:  Is the product type one of the following? Review both 3.1.a and 3.1.b. ☐YES    ☒NO \n3.1.a All Intertek Marks 3.1.b ETL/WH Marks include the following in addition to 3.1.a',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 1,
#        'similarity_score': 0.7764144820232556,
#        'preview_text': 'System Components .............................................................................................................. 7 \nFront Panel ................................ ................................ ................................ ................................ ....8 \nBack Panel ................................ ................................ ................................ ................................ .....9 \nInfinity MPA ................................ ................................ ................................ ................................ . 11 \nChapter 2. Upon Receiving the Infinity MTx ......................................................................... 12 \nSite Preparations ................................ ................................ ................................ ..........................  12',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'}],
#      'image_support': [{'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf_page_6.png',
#        'image_file': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf_page_6.png',
#        'pdf_file': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 6,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf/page_6.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'}],
#      'evidence_type': 'image',
#      'confidence': 90},
#     {'question_row': 4,
#      'question_column': 0,
#      'field': 'Ratings\t:',
#      'answer_row': 4,
#      'answer_column': 2,
#      'value': '100-240VAC, 5.9-2.7A, 50/60Hz; 24VDC',
#      'task_type': 'extraction',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': True,
#      'page_no': 2,
#      'custom_prompt': 'Provide the ratings of the equipment.',
#      'text_support': [{'filename': 'RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml',
#        'page': 1,
# ...
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/celFE_isol.docx'}],
#      'image_support': [{'filename': 'CFE-4LB011-E__1___1_.pdf_page_1.png',
#        'image_file': 'CFE-4LB011-E__1___1_.pdf_page_1.png',
#        'pdf_file': 'CFE-4LB011-E__1___1_.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/CFE-4LB011-E__1___1_.pdf/page_1.png',
#        'file_url': None},
#       {'filename': 'celFE_isol.pdf_page_1.png',
#        'image_file': 'celFE_isol.pdf_page_1.png',
#        'pdf_file': 'celFE_isol.pdf',
#        'page': 1,
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/pdf_images/celFE_isol.pdf/page_1.png',
#        'file_url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/celFE_isol.docx'}],
#      'evidence_type': 'both',
#      'confidence': 95},
#     {'clause_row': 498,
#      'clause_column': 0,
#      'clause': '6.10.2',
#      'question_row': 498,
#      'question_column': 1,
#      'field': 'Fitting of non-detachable mains supply cords',
#      'answer_row': 498,
#      'answer_column': 2,
#      'value': None,
#      'task_type': 'remark',
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'dependency_rows': [499, 502],
#      'page_no': 26},
#     {'clause_row': 498,
#      'clause_column': 0,
#      'clause': '6.10.2',
#      'question_row': 498,
#      'question_column': 1,
#      'field': 'Fitting of non-detachable mains supply cords',
#      'answer_row': 498,
#      'answer_column': 3,
#      'value': None,
#      'task_type': 'verdict',
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'dependency_rows': [499, 502],
#      'page_no': 26},
#     {'clause_row': 499,
#      'clause_column': 0,
#      'clause': '6.10.2.1',
#      'question_row': 499,
#      'question_column': 1,
#      'field': 'Cord entry',
#      'answer_row': 499,
#      'answer_column': 2,
#      'value': None,
#      'task_type': 'remark',
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'dependency_rows': [500, 501],
#      'page_no': 26},
#     {'clause_row': 499,
#      'clause_column': 0,
#      'clause': '6.10.2.1',
#      'question_row': 499,
#      'question_column': 1,
#      'field': 'Cord entry',
#      'answer_row': 499,
#      'answer_column': 3,
#      'value': '—',
#      'task_type': 'verdict',
#      'user_editable': False,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'dependency_rows': [500, 501],
#      'page_no': 26},
#     {'clause_row': 500,
#      'clause_column': 0,
#      'clause': None,
#      'question_row': 500,
#      'question_column': 1,
#      'field': 'inlet or bushing with a smoothly rounded opening; or',
#      'answer_row': 500,
#      'answer_column': 2,
#      'custom_prompt': 'Verify that the fitting of non-detachable mains supply cords uses an inlet or bushing with a smoothly rounded opening.',
#      'value': 'TBD-Info not available',
#      'task_type': 'remark',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': False,
#      'dependency_rows': None,
#      'page_no': 26,
#      'confidence': 0,
#      'text_support': [{'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 9,
#        'similarity_score': 0.7898068985444385,
#        'preview_text': 'Page 10 of 59 \nperforming this step. Ensure both systems are decompressed before removing the tubing \nby pushing the small tab located on the instrument’s compressed air inlet. \n3. Air Intake Fan – Provides cooling for internal electrical components and power supply. CAUTION \nDo not block – Ensure at least 6” of clearance behind instrument \n4. Power Connection Port – Auxiliary port that powers the instrument. The C13 to 5-15 power cord \ncan be plugged directly into the Infinity MTx, with the opp',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml',
#        'page': 1,
#        'similarity_score': 0.7862243024299831,
#        'preview_text': 'Cap Discharge Test\nStability Test\nRigidity Test (Static)\nRigidity Test (Dynamic)\nDrop Test (Equipment other than hand-held equipment)\nTemperature test\nResistance to Heat "Non-metallic enclosures"\nCleaning Test\nSpillage Test\nHi Kenneth,\nWe will update the label to match those ratings from the power supply.\nAs for the list of countries, we provided that information earlier to the EMC team. If necessary, I can also follow up internally to get the exact list again.\nOn Thu, Oct 5, 2023 at 11:53\u202fAM Al',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 12,
#        'similarity_score': 0.7771404403840584,
#        'preview_text': '6.7.1. Connect one end of the small diameter tubing to one end of the larger diameter tubing  \nprovided with the compressor. \n6.7.2. Remove the remaining rubber stopper from the compressor. \n6.7.3. Insert the other end of the small tubing into the open port. \nPlaceholder: Image of \nrubber stopper being \nreplaced with filter',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 8,
#        'similarity_score': 0.7760508108162443,
#        'preview_text': 'Page 9 of 59 \n \nBack Panel \n1. Exhaust Air Vents – Used to vent air out of the instrument. CAUTION Do not block – Ensure at \nleast 6” of clearance behind instrument \n2. Compressed Air Inlet – The primary attachment point of the instrument –compatible with ¼” NPT \nPressure line tubing fitted with a push-to-connect fitting. The instrument should be attached to a \npressurized air source of 100 PSI for optimal functioning. The pressurized air should not exceed \n120 PSI.  \na. Connecting the tubing: E',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 44,
#        'similarity_score': 0.7750711320983004,
#        'preview_text': 'Page 45 of 59 \n \nIndicates the fuse rating for the device when replacing the fuse use one of the \nsame type and rating as marked on the label. \n \nIndicates the AC power requirements of the device. Refer to the label to ensure \nthat the facility can handle the requirements.  \n \nResearch only use - “For Research Use Only. Not for use in diagnostic \nprocedures.”',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'}],
#      'image_support': [],
#      'similarity_query': 'Verify that the fitting of non-detachable mains supply cords uses an inlet or bushing with a smoothly rounded opening.',
#      'vector_search_based_on': 'question',
#      'evidence_source': {'type': 'text',
#       'files': {'text_files': ['CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#         'RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml'],
#        'image_files': []}}},
#     {'clause_row': 500,
#      'clause_column': 0,
#      'clause': None,
#      'question_row': 500,
#      'question_column': 1,
#      'field': 'inlet or bushing with a smoothly rounded opening; or',
#      'answer_row': 500,
#      'answer_column': 3,
#      'custom_prompt': 'Verify that the fitting of non-detachable mains supply cords uses an inlet or bushing with a smoothly rounded opening.',
#      'value': None,
#      'task_type': 'verdict',
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'dependency_rows': None,
#      'page_no': 26},
#     {'clause_row': 501,
#      'clause_column': 0,
#      'clause': None,
#      'question_row': 501,
#      'question_column': 1,
#      'field': 'insulated cord guard protruding >5 D (diameter)',
#      'answer_row': 501,
#      'answer_column': 2,
#      'custom_prompt': 'Verify that the insulated cord guard for a non-detachable mains supply cord protrudes more than 5 times the cord diameter.',
#      'value': 'TBD-Info available',
#      'task_type': 'remark',
#      'user_editable': True,
#      'ai_fillable': True,
#      'accuracy_level': False,
#      'dependency_rows': None,
#      'page_no': 26,
#      'confidence': 0,
#      'text_support': [{'filename': 'celFE_isol.pdf',
#        'page': 0,
#        'similarity_score': 0.8038282347539819,
#        'preview_text': 'IEC 61010-1    \nClause  Requirement — Test   Result — Remark  Verdict  \n   \n6  TABLE: Protection against electric shock - Block diagram of system Form A.5  P  \n \nPollution degree :2  Overvoltage category: Ⅱ  \nLocation or  Insulation \ntype  \nMaximum \nworking  \nCREEPAGE Distance \n(NOTE 3)  \nCLEARANCE \n(NOTE 3)  \nTest \nvoltage  \nComments  \ndescription  (NOTE 1)  voltage  \n(NOTE 2)  \nPWB \nmm  \nCTI  Other \nmm  \nCTI  mm  (NOTE 2) \nV  \n  \nA  BI  240Vrms  1.5  ≧100  3.0  >100  1.5    Line to \nNeutral \nb',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/celFE_isol.docx'},
#       {'filename': 'RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml',
#        'page': 1,
#        'similarity_score': 0.7949687236610147,
#        'preview_text': 'Cap Discharge Test\nStability Test\nRigidity Test (Static)\nRigidity Test (Dynamic)\nDrop Test (Equipment other than hand-held equipment)\nTemperature test\nResistance to Heat "Non-metallic enclosures"\nCleaning Test\nSpillage Test\nHi Kenneth,\nWe will update the label to match those ratings from the power supply.\nAs for the list of countries, we provided that information earlier to the EMC team. If necessary, I can also follow up internally to get the exact list again.\nOn Thu, Oct 5, 2023 at 11:53\u202fAM Al',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 43,
#        'similarity_score': 0.7921120406638835,
#        'preview_text': 'Page 44 of 59 \n  \nThis product conforms to UL 61010-1, CAN/CSA C22.2 No.61010-1 \n“Safety Requirements for Electrical Equipment for Measurement, \nControl, and Laboratory Use, Part l: General Requirements.” \nInstruments bearing the ETL symbol are certified by ETLProduct \nServices to be in conformance with the applicable safety standard for \nthe US and Canada.  \n \n \nWEEE (Waste Electrical and Electronic Equipment) symbol indicates \nthat this product should not be disposed of in unsorted municipal',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 9,
#        'similarity_score': 0.789835274652292,
#        'preview_text': 'Page 10 of 59 \nperforming this step. Ensure both systems are decompressed before removing the tubing \nby pushing the small tab located on the instrument’s compressed air inlet. \n3. Air Intake Fan – Provides cooling for internal electrical components and power supply. CAUTION \nDo not block – Ensure at least 6” of clearance behind instrument \n4. Power Connection Port – Auxiliary port that powers the instrument. The C13 to 5-15 power cord \ncan be plugged directly into the Infinity MTx, with the opp',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'},
#       {'filename': 'CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#        'page': 46,
#        'similarity_score': 0.7862829871416716,
#        'preview_text': 'Page 47 of 59 \n \n \nSafety  \n \nEU Directive 2014/35/EU – Low Voltage Directive \nIEC/EN/UL/BS 61010-1 – Safety requirements for electrical equipment for measurement, control, and \nlaboratory use – Part 1: General requirement.  \nCAN/CSA C22.2 No. 61010-1 – Safety requirements for electrical equipment for measurement, control, \nand laboratory use – Part 1: General requirement. \nIEC/EN/UL/BS 61010-2-081 - Safety requirements for electrical equipment for measurement, control, and \nlaboratory use – Par',
#        'url': 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/CELLFE_1002/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx'}],
#      'image_support': [],
#      'similarity_query': 'Verify that the insulated cord guard for a non-detachable mains supply cord protrudes more than 5 times the cord diameter.',
#      'vector_search_based_on': 'question',
#      'evidence_source': {'type': 'text',
#       'files': {'text_files': ['CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf',
#         'RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614.eml',
#         'celFE_isol.pdf'],
#        'image_files': []}}},
#     {'clause_row': 501,
#      'clause_column': 0,
#      'clause': None,
#      'question_row': 501,
#      'question_column': 1,
#      'field': 'insulated cord guard protruding >5 D (diameter)',
#      'answer_row': 501,
#      'answer_column': 3,
#      'custom_prompt': 'Verify that the insulated cord guard for a non-detachable mains supply cord protrudes more than 5 times the cord diameter.',
#      'value': None,
#      'task_type': 'verdict',
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'dependency_rows': None,
#      'page_no': 26},
#     {'clause_row': 502,
#      'clause_column': 0,
#      'clause': '6.10.2.2',
#      'question_row': 502,
#      'question_column': 1,
#      'field': 'Cord anchorage',
#      'answer_row': 502,
#      'answer_column': 2,
#      'value': None,
#      'task_type': 'remark',
#      'user_editable': True,
#      'ai_fillable': False,
#      'accuracy_level': False,
#      'dependency_rows': [503, 504, 505, 506, 507, 508, 509, 510],
#      'page_no': 26},
#     ...]}]}

# %%
# --------------------------------------------------
# Initialize Project Paths & Progress
# --------------------------------------------------

paths = project_paths(project_id)

print(f"[RUNTIME] Running project {project_id}")

TOTAL = 22
step = 0

conn_str = AZURE_CONN_STRING
# Out:
# [RUNTIME] Running project B105581614

# %%
# --------------------------------------------------
# Prepare workspace
# --------------------------------------------------

if paths["SRC"].parent.exists():
    shutil.rmtree(paths["SRC"].parent)
paths["SRC"].mkdir(parents=True, exist_ok=True)

print(paths["SRC"])

step += 1; progress(step, TOTAL, "Starting pipeline")
# Out:
# C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files
# {"type": "progress", "step": 3, "total": 16, "percent": 18.75, "message": "Starting pipeline", "ts": 1773131708.8398747}

# %%
# --------------------------------------------------
# Blob cleanup
# --------------------------------------------------
device_prefix = f"Documents/{project_id}/source_documents/device_images"
count = utils.delete_folder_if_exists(
    AZURE_BLOB_CONNECTION_STRING,
    BLOB_CONTAINER_NAME,
    device_prefix
)
print(device_prefix)
step += 1; progress(step, TOTAL, "Device images cleaned", {"deleted": count})
# Out:
# Documents/B105581614/source_documents/device_images
# {"type": "progress", "step": 5, "total": 16, "percent": 31.25, "message": "Device images cleaned", "ts": 1773131832.0319662, "extra": {"deleted": 0}}

# %%
# --------------------------------------------------
# TRF document
# --------------------------------------------------
trf_blob = get_trf_blob_url(
    AZURE_BLOB_CONNECTION_STRING,
    BLOB_CONTAINER_NAME,
    f"Documents/{project_id}/Generated_trf_Report/final_output_{project_id}.docx"
)

print(trf_blob)

step += 1; progress(step, TOTAL, "Listing blob URLs")
# Out:
# https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/Generated_trf_Report/final_output_B105581614.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21:10:06Z&st=2026-01-19T12:55:06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# {"type": "progress", "step": 6, "total": 16, "percent": 37.5, "message": "Listing blob URLs", "ts": 1773132762.8868117}

# %%
prefix = f"Documents/{project_id}/source_documents"
blob_urls = get_blob_urls(conn_str, container)

blob_urls.append(trf_blob)

print(blob_urls)
# Out:
# ['https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Accepted_-_Gener8_LLC_-_Qu-01390131-0%20%281%29.msg?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CFE-4LB011-E%20%281%29%20%281%29.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CFE_block_diagram.png?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CellFE_Infinity_MTx_Operating_Manual.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Cell_Gener8_Agent_Agreement_2018_1_.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Client_Information_Sheet_-_FUS_CIS_1_.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/PastedGraphic-1.png?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Qu-01390131-0.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614%20%281%29.eml?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents ...

# %%
step += 1; progress(step, TOTAL, "Downloading TRF")
extracted_texts, image_urls, _, _ = utils.process_blob_urls_2(
    blob_urls,
    AZURE_BLOB_CONNECTION_STRING,
    BLOB_CONTAINER_NAME,
    download_dir=paths["SRC"],
    keep_files=True,
    verbose=True
)
# Out:
# {"type": "progress", "step": 7, "total": 16, "percent": 43.75, "message": "Downloading TRF", "ts": 1773132856.5226548}
# [INFO] Processing URL #0: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Accepted_-_Gener8_LLC_-_Qu-01390131-0%20%281%29.msg?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Processing URL #1: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CFE-4LB011-E%20%281%29%20%281%29.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Downloaded PDF recorded: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\CFE-4LB011-E (1) (1).pdf
# [INFO] Processing URL #2: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CFE_block_diagram.png?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Detected image, skipping download: CFE_block_diagram.png
# [INFO] Processing URL #3: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Converted DOCX to PDF: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.docx -> C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf
# [INFO] Processing URL #4: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CellFE_Infinity_MTx_Operating_Manual.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Converted DOCX to PDF: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\CellFE_Infinity_MTx_Operating_Manual.docx -> C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\CellFE_Infinity_MTx_Operating_Manual.pdf
# [INFO] Processing URL #5: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Cell_Gener8_Agent_Agreement_2018_1_.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Downloaded PDF recorded: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\Cell_Gener8_Agent_Agreement_2018_1_.pdf
# [INFO] Processing URL #6: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Client_Information_Sheet_-_FUS_CIS_1_.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Downloaded PDF recorded: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\Client_Information_Sheet_-_FUS_CIS_1_.pdf
# [INFO] Processing URL #7: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Converted DOCX to PDF: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.docx -> C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf
# [INFO] Processing URL #8: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Downloaded PDF recorded: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf
# [INFO] Processing URL #9: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/PastedGraphic-1.png?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Detected image, skipping download: PastedGraphic-1.png
# [INFO] Processing URL #10: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Qu-01390131-0.pdf?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Downloaded PDF recorded: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\Qu-01390131-0.pdf
# [INFO] Processing URL #11: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/RE__External_Re__Intertek_Order_Qu-01390131-0_processed_-_Gener8_LLC_Project_G105581614%20%281%29.eml?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Processing URL #12: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/Risk%20Assessment%20CFE_28nov%20%281%29.xlsx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Processing URL #13: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/celFE_isol.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Converted DOCX to PDF: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\celFE_isol.docx -> C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\celFE_isol.pdf
# [INFO] Processing URL #14: https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/Generated_trf_Report/final_output_B105581614.docx?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21:10:06Z&st=2026-01-19T12:55:06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D
# [INFO] Converted DOCX to PDF: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\final_output_B105581614.docx -> C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\src_files\final_output_B105581614.pdf

# %%
step += 1; progress(step, TOTAL, "Downloading images from blobs")
image_urls = get_image_urls_from_container_sas()
print(image_urls)
# Out:
# {"type": "progress", "step": 8, "total": 16, "percent": 50.0, "message": "Downloading images from blobs", "ts": 1773133213.195439}
# ['https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/CFE_block_diagram.png?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D', 'https://stintertekesusdev.blob.core.windows.net/stintertekesusdev-blob/Documents/B105581614/source_documents/PastedGraphic-1.png?sv=2024-11-04&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2126-01-19T21%3A10%3A06Z&st=2026-01-19T12%3A55%3A06Z&spr=https&sig=K1nhnwEPGX%2FBKxWejkJK5NiGpUYZbaDNhlE9D303W6E%3D']

# %%
# --------------------------------------------------
# CIS Extraction
# --------------------------------------------------

step += 1; progress(step, TOTAL, "Extracting CIS info")
cis_info = extract_cis()
extracted_texts += cis_info
# Out:
# {"type": "progress", "step": 9, "total": 16, "percent": 56.25, "message": "Extracting CIS info", "ts": 1773133296.2504878}
#  → Not editable. Skipping.
#  → Not editable. Skipping.
#  → Not editable. Skipping.
#  ✔ Flattened PDF created.
#  → Not editable. Skipping.
#  ✔ Flattened PDF created.
#  → Not editable. Skipping.
#  → Not editable. Skipping.
#  → Not editable. Skipping.
#  → Not editable. Skipping.

# %%
# --------------------------------------------------
# Save extracted text
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Saving extracted text")
with open(paths["BASE"] / "extracted.txt", "w", encoding="utf-8") as f:
    json.dump(extracted_texts, f, indent=2)
# Out:
# {"type": "progress", "step": 10, "total": 16, "percent": 62.5, "message": "Saving extracted text", "ts": 1773133322.338054}

# %%
# --------------------------------------------------
# Collect PDFs
# --------------------------------------------------
pdf_paths = [paths["SRC"] / f for f in os.listdir(paths["SRC"]) if f.lower().endswith(".pdf")]

# %%
print(pdf_paths)
# Out:
# [WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/celFE_isol.pdf'), WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/CellFE_Infinity_MTx_Operating_Manual-jsg-11-16-2023_Final_1_.pdf'), WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/CellFE_Infinity_MTx_Operating_Manual.pdf'), WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/CFE-4LB011-E (1) (1).pdf'), WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/final_output_B105581614.pdf'), WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/Gener8_SAF_Electrical_Risk_Assessment_Form_2022-11-30.pdf'), WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/Gener_8_PO_P70909_INTERTEK_TESTING_SERVICES__EMC_Safety_Testings_Proj_13403_-.pdf'), WindowsPath('C:/Users/affine/Downloads/InterTek-AI-Repo/Backend/data/cdr_files/B105581614/src_files/Qu-01390131-0.pdf')]

# %%
# --------------------------------------------------
# Container Creation Cosmos
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Creating DB/container (Cosmos)")
container_obj = utils.create_db_and_container()

db = cosmos_client.get_database_client(DB_NAME)
print(f"db_created:{db}", flush=True)
# Out:
# {"type": "progress", "step": 11, "total": 16, "percent": 68.75, "message": "Creating DB/container (Cosmos)", "ts": 1773133369.6571074}
# db_created:<DatabaseProxy [dbs/ragdatabase_new_itk]>

# %%
# --------------------------------------------------
# Vector store
# --------------------------------------------------

step += 1; progress(step, TOTAL, "Building embeddings + vector store")
# embeddings = utils.build_embeddings()
vs = build_vectorstore()

step += 1; progress(step, TOTAL, "Chunking + ingesting documents into vector store")
chunks = utils.load_and_split_pdfs_text(pdf_paths, extracted_texts=extracted_texts)
utils.ingest_chunks(vs, chunks, max_workers=5, batch_size=10)
# Out:
# {"type": "progress", "step": 12, "total": 16, "percent": 75.0, "message": "Building embeddings + vector store", "ts": 1773133389.2983704}
# {"type": "progress", "step": 13, "total": 16, "percent": 81.25, "message": "Chunking + ingesting documents into vector store", "ts": 1773133391.1250281}

# %%
# --------------------------------------------------
# Reference generation
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Building references")
ref = build_ref(input_json)

step += 1; progress(step, TOTAL, "Generating references")
template = references_main(vs, ref)

progress(step, TOTAL, "References Generated")
# Out:
# {"type": "progress", "step": 15, "total": 16, "percent": 93.75, "message": "Building references", "ts": 1773134613.3937352}
# {"type": "progress", "step": 16, "total": 16, "percent": 100.0, "message": "Generating references", "ts": 1773134613.3967245}
# {"type": "progress", "step": 16, "total": 16, "percent": 100.0, "message": "References Generated", "ts": 1773134653.0115023}

# %%
# --------------------------------------------------
# Description
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Generating description")
product_info = description_main(vs, ref)
description = build_product_section_items(product_info, trf_blob)
progress(step, TOTAL, "Descriptions Generated")
# Out:
# {"type": "progress", "step": 17, "total": 16, "percent": 106.25, "message": "Generating description", "ts": 1773134658.3636417}
# {"type": "progress", "step": 17, "total": 16, "percent": 106.25, "message": "Descriptions Generated", "ts": 1773134660.5974936}

# %%
# --------------------------------------------------
# Features
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Running features")
features = features_tools_main(vs, image_urls, run_audit=True)

step += 1; progress(step, TOTAL, "Moving device images")
moved = move_device_images_in_blob(
    image_urls=image_urls,
    connection_string=configs.AZURE_BLOB_CONNECTION_STRING,
    container_name=configs.BLOB_CONTAINER_NAME,
)
progress(step, TOTAL, "Device images moved", {"count": len(moved)})

# %%
# --------------------------------------------------
# Features
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Running features")
features = features_tools_main(vs, image_urls, run_audit=True)
progress(step, TOTAL, "Features Generated")
# Out:
# {"type": "progress", "step": 18, "total": 16, "percent": 112.5, "message": "Running features", "ts": 1773134693.7622087}
# {"type": "progress", "step": 18, "total": 16, "percent": 112.5, "message": "Features Generated", "ts": 1773134742.09001}

# %%
step += 1; progress(step, TOTAL, "Moving device images")
moved = move_device_images_in_blob(
    image_urls=image_urls,
    connection_string=configs.AZURE_BLOB_CONNECTION_STRING,
    container_name=configs.BLOB_CONTAINER_NAME,
)
progress(step, TOTAL, "Device images moved", {"count": len(moved)})
# Out:
# {"type": "progress", "step": 19, "total": 16, "percent": 118.75, "message": "Moving device images", "ts": 1773134744.0102522}
# {"type": "progress", "step": 19, "total": 16, "percent": 118.75, "message": "Device images moved", "ts": 1773134747.4104555, "extra": {"count": 0}}

# %%
# --------------------------------------------------
# Sheets 3 & 4
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Running Sheets 3 & 4")
run_sheet_3_and_4_agentic(vs=vs)
progress(step, TOTAL, "Sheet 3 and 4 Generated")
# Out:
# {"type": "progress", "step": 20, "total": 16, "percent": 125.0, "message": "Running Sheets 3 & 4", "ts": 1773134750.593932}
# Guide text length: 65093
# Guide text length: 65093
#
# --- Extracting Components ---
# Image comps: 0, Guide comps: 52
# Combined unique: 52
# ✔ Excel written: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\s4c2_cc_raw.xlsx
# ✔ Extraction completed successfully
#
# --- Classifying Components ---
# ✔ Classified excel written: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\s4c2_cc_filtered.xlsx
#
# --- Deduplicating ---
# ✔ Deduplicated excel written: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\s4c2_cc_final.xlsx
# ✔ JSON created successfully: C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\s4.json
# {"type": "progress", "step": 20, "total": 16, "percent": 125.0, "message": "Sheet 3 and 4 Generated", "ts": 1773134884.346462}

# %%
# --------------------------------------------------
# Post-processing
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Post processing")

with open(paths["CDR_PAYLOAD"], "r") as f:
    cdr = json.load(f)
with open(paths["S3"], "r") as f:
    s3 = json.load(f)
with open(paths["S4"], "r") as f:
    s4 = json.load(f)

cdr = post_process_cdr(cdr, template, description, features, s3, s4)

progress(step, TOTAL, "CDR Post Processed")
# Out:
# {"type": "progress", "step": 21, "total": 16, "percent": 131.25, "message": "Post processing", "ts": 1773134922.4668388}
# {"type": "progress", "step": 21, "total": 16, "percent": 131.25, "message": "CDR Post Processed", "ts": 1773134922.4858007}

# %%
# --------------------------------------------------
# Add urls to citations
# --------------------------------------------------

cdr, _ = utils.add_urls_sheet_1_and_6(cdr, configs.AZURE_BLOB_CONTAINER_SAS_URL)

# %%
# --------------------------------------------------
# save final json
# --------------------------------------------------

with open(paths["FINAL_JSON"], "w", encoding="utf-8") as f:
    json.dump(cdr, f, indent=2, ensure_ascii=False)
    
print(f"Final JSON saved at path : {paths["FINAL_JSON"]}")
# Out:
# Final JSON saved at path : C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\cdr_files\B105581614\cdr_payload_v5_updated.json

# %%
# --------------------------------------------------
# Excel
# --------------------------------------------------
step += 1; progress(step, TOTAL, "Generating Excel")
compiler.fill_excel_from_json(cdr, output_excel_path)

print(f"Excel saved at path : {output_excel_path}")


progress(TOTAL, TOTAL, "Done", {"project": project_id})
# Out:
# {"type": "progress", "step": 24, "total": 16, "percent": 150.0, "message": "Generating Excel", "ts": 1773136041.4743135}
# Excel saved at path : C:\Users\affine\Downloads\InterTek-AI-Repo\Backend\data\B105581614\iec_output_sheet_B105581614.xlsx
# {"type": "progress", "step": 16, "total": 16, "percent": 100.0, "message": "Done", "ts": 1773136042.4890463, "extra": {"project": "B105581614"}}

# %%
# --------------------------------------------------
# Delete Cosmos Container
# --------------------------------------------------

Container_name = f"vectorstorecontainer_new_itk_text_{user_id}_{project_id}"
utils.delete_cosmos_container(configs.COSMOS_URL,configs.COSMOS_KEY,configs.DB_NAME,Container_name)
print(f"Container Deleted : {Container_name}")
# Out:
# Container 'vectorstorecontainer_new_itk_text_test_user_B105581614' or database 'ragdatabase_new_itk' not found.
# Container Deleted : vectorstorecontainer_new_itk_text_test_user_B105581614
